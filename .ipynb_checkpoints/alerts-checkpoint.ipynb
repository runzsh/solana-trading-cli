# %% [markdown]
# #### **Import**

# %%
import re
import os
import requests
import pandas as pd
from pathlib import Path
from datetime import datetime, timedelta, timezone

# %% [markdown]
# #### **Process:** Raydium

# %%
logs_folder = Path('./logs')
log_files = list(logs_folder.glob('stream_raydium_pools_*.log'))
if not log_files:
    raise FileNotFoundError("No .log files found in ./logs")
raydium_log = max(log_files, key=os.path.getmtime)
print(f"Parsing latest Raydium log file: {raydium_log.name}")
# Out:
# Parsing latest Raydium log file: stream_raydium_pools_2025-04-28_10-00-01.log

# %%
entries = []
current_entry = {}

with open(raydium_log, 'r') as file:
    for line in file:
        timestamp_match = re.match(r"\[(.*?)\]", line)
        if not timestamp_match:
            continue
        timestamp_str = timestamp_match.group(1)
        timestamp = pd.to_datetime(timestamp_str)
        if timestamp.tzinfo is None:
            timestamp = timestamp.tz_localize('UTC')
        else:
            timestamp = timestamp.tz_convert('UTC')

        if "Pool Address:" in line:
            pool = line.strip().split("Pool Address:")[1].strip()
            current_entry = {'timestamp': timestamp, 'pool': pool}
        elif "Initial Balance:" in line and current_entry:
            try:
                balance = float(line.strip().split("Initial Balance:")[1].strip().split()[0])
                current_entry['initial_balance_sol'] = balance
                entries.append(current_entry)
                current_entry = {}
            except ValueError:
                continue

raydf = pd.DataFrame(entries)

# %%
raydf
# Out:
#                     timestamp                                          pool  \
# 0   2025-04-28 10:02:42+00:00  GMZNDbpPifEQpBxQxXNy5fBLFAhuDLfYQ9JSRG8Jim1B
# 1   2025-04-28 10:09:30+00:00  8wMfRFJvZQxyw4crupCidMwebuMoS9b5raAqXBSKJKnF
# 2   2025-04-28 10:15:29+00:00  7YgRwGTGCoQJY3nLxJgx4KjRAy7neoAAL23jEar2sf1H
# 3   2025-04-28 10:32:57+00:00  HRJKPunz7MbaPe8FmzgNUAc84uZSnALoewnYjPQayddi
# 4   2025-04-28 10:33:32+00:00  3frcUxxMnwGwAwa6UT8tL961LgVpBn6jkVWi66Zhim6c
# ..                        ...                                           ...
# 164 2025-04-29 01:53:12+00:00  BhmWdrRqez9Cq69z53MPURdYUS1z6cedKvoWGdM6WX8N
# 165 2025-04-29 02:03:23+00:00  EL8hdRsuxJSBAL2p6i5cC3GMJpkitH8tizjuZimq5Mjr
# 166 2025-04-29 02:05:39+00:00   h8wWSeBdmi83vt5qBMjFZJudU8vBY8BPCtXkV4AmVBn
# 167 2025-04-29 02:11:38+00:00  BuSQrw9ZcsoPAaJBz8Ax5WdebePC8gMhzGqZzbwSoFbY
# 168 2025-04-29 02:15:19+00:00  FUmX6dCdviHF9wfXKseRps4qQ3UdffJ2MxU7NCmWrPWJ
#
#      initial_balance_sol
# 0             150.000000
# 1             150.000000
# 2               0.300000
# 3               1.000000
# 4               1.000000
# ..                   ...
# 164           351.000000
# 165             0.150000
# 166             0.100000
# 167             0.384446
# 168            84.990000
#
# [169 rows x 3 columns]

# %% [markdown]
# #### **Process:** PumpFun

# %%
logs_folder = Path('./logs')
log_files = list(logs_folder.glob('stream_pumpfun_pools_*.log'))
if not log_files:
    raise FileNotFoundError("No .log files found in ./logs")
pump_log = max(log_files, key=os.path.getmtime)
print(f"Parsing latest PumpFun log file: {pump_log.name}")
# Out:
# Parsing latest PumpFun log file: stream_pumpfun_pools_2025-04-28_10-00-01.log

# %%
# Regular expression to match the timestamp and signature
pattern = r"\[(.*?)\]\s*{\s*signature:\s*'([^']+)'"

# Read the file
with open(pump_log, 'r') as file:
    log_data = file.read()

# Find all matches
matches = re.findall(pattern, log_data)

# Create DataFrame
pumpdf = pd.DataFrame(matches, columns=['timestamp', 'signature'])

# Convert timestamp string to datetime
pumpdf['timestamp'] = pd.to_datetime(pumpdf['timestamp'])

# %% [markdown]
# #### **Crunching**

# %%
pump_count = len(pumpdf[pumpdf['timestamp'] >= (datetime.now(timezone.utc) - timedelta(hours=12))])

# %%
ray_slice = raydf[raydf['timestamp'] >= (datetime.now(timezone.utc) - timedelta(hours=12))]

# %%
ray_trade = len(ray_slice['initial_balance_sol'] >= 150)

# %%
pump_count = 192
ray_slice = 148
ray_trade = 53

# %% [markdown]
# #### **Alerts**

# %%
# Alertatron Webhook configure
webhook_url = "https://alertatron.com/webhook/incoming/9a5804fd-b16d-423b-a932-403cce5e59e3"

# %%
# Build PumpSwap message
message = f"*PumpSwap: New Pools 12H* ~ [JLabs Digital](http://jlabsdigital.com/)\n"
message += "```\n"
message += f"New Pools: {pump_count}\n"
message += f"Tradeable Pools: {pump_count}\n"
message += "```\n"
message += "\n----\n"
message += "(Inbox)"

payload = {
    'text': message
}
response = requests.post(webhook_url, json=payload)

if response.status_code == 200:
    current_time = datetime.now().strftime('%H:%M')
    print(f"Telegram alert for PumpSwap sent successfully at {current_time}!")
else:
    print(f"Failed to send Telegram alert. Status code: {response.status_code}")
    print(response.text)

# %%
# Build PumpSwap message
message = f"*Raydium: New Pools 12H* ~ [JLabs Digital](http://jlabsdigital.com/)\n"
message += "```\n"
message += f"New Pools: {ray_slice}\n"
message += f"Tradeable Pools: {ray_trade}\n"
message += "```\n"
message += "\n----\n"
message += "(Inbox)"

payload = {
    'text': message
}
response = requests.post(webhook_url, json=payload)

if response.status_code == 200:
    current_time = datetime.now().strftime('%H:%M')
    print(f"Telegram alert for Raydium sent successfully at {current_time}!")
else:
    print(f"Failed to send Telegram alert. Status code: {response.status_code}")
    print(response.text)
# Out:
# Telegram alert for Raydium sent successfully at 21:23!
